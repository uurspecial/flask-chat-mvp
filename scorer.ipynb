# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
# -------------------------
# 1️⃣ 掛載 Google Drive
# -------------------------
from google.colab import drive
drive.mount('/content/drive')

# -------------------------
# 2️⃣ 指定 JSONL 路徑
# -------------------------
import os
from datasets import load_dataset

jsonl_path = "/content/drive/MyDrive/dataset.jsonl"  # ✅ 改這裡成你的實際路徑

# 檢查檔案是否存在
assert os.path.exists(jsonl_path), f"❌ 找不到檔案：{jsonl_path}"

# -------------------------
# 3️⃣ 載入資料集
# -------------------------
ds = load_dataset("json", data_files=jsonl_path, split="train")

# -------------------------
# 4️⃣ 統一欄位名稱 sentence / label
# -------------------------
def unify(example):
    # sentence 欄位名稱統一
    sentence = (
        example.get("sentence")
        or example.get("prompt")
        or example.get("text")
        or ""
    )

    # label 欄位名稱統一
    if "completion" in example and example["completion"] is not None:
        label = int(example["completion"])
    elif "level" in example and example["level"] is not None:
        label = int(example["level"])
    else:
        # 若資料沒有 label，可設為 -1 以便過濾
        label = -1

    return {"sentence": sentence, "label": label}

ds = ds.map(unify)

# 過濾掉 label 無效的資料
ds = ds.filter(lambda x: x["label"] != -1)

# -------------------------
# 5️⃣ 檢查結果
# -------------------------
print("✅ 成功載入 dataset.jsonl")
print("📊 總筆數:", len(ds))
print("📝 範例資料：")
print(ds[0])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/165 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/165 [00:00<?, ? examples/s]
# ✅ 成功載入 dataset.jsonl
# 📊 總筆數: 165
# 📝 範例資料：
# {'prompt': '這句話的討人厭程度 (1-5)：好像還行吧。', 'completion': '1', 'sentence': '這句話的討人厭程度 (1-5)：好像還行吧。', 'label': 1}

# %%
# 移除無效或缺 label 筆
ds = ds.filter(lambda x: x["sentence"] is not None and x["sentence"].strip() != "" and x["label"] is not None)

# 轉 label 範圍到 0..4（若原本就是 1..5 ）
def normalize_label(x):
    if x["label"] > 5:  # 保險檢查
        x["label"] = 5
    if x["label"] < 1:
        x["label"] = 1
    x["label"] = int(x["label"]) - 1
    return x

ds = ds.map(normalize_label)

# 切 train / val（80/20）
ds = ds.train_test_split(test_size=0.2, seed=42)
print("train:", len(ds["train"]), "val:", len(ds["test"]))


# 確認 label 範圍
for split in ['train', 'test']:
    labels = [x['label'] for x in ds[split]]
    print(split, "min:", min(labels), "max:", max(labels))
# Out:
# Filter:   0%|          | 0/165 [00:00<?, ? examples/s]
# Map:   0%|          | 0/165 [00:00<?, ? examples/s]
# train: 132 val: 33
# train min: 0 max: 4
# test min: 0 max: 4

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "hfl/chinese-roberta-wwm-ext"
num_labels = 5

# 1️⃣ 載入 tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# 2️⃣ 新增 pad token
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# 3️⃣ 載入模型
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=num_labels)

# 4️⃣ 讓模型 embedding 對應新 pad token
model.resize_token_embeddings(len(tokenizer))

# 5️⃣ 設定 pad_token_id
model.config.pad_token_id = tokenizer.pad_token_id

# 6️⃣ 設定 device 關掉
#device = "cuda" if torch.cuda.is_available() else "cpu"
#model = model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hfl/chinese-roberta-wwm-ext and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
max_len = 128
def tok_fn(batch):
    return tokenizer(batch["prompt"], truncation=True, padding="max_length", max_length=max_len)

ds_encoded = ds.map(lambda x: tok_fn(x), batched=True)
ds_encoded.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
# Out:
# Map:   0%|          | 0/132 [00:00<?, ? examples/s]
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]

# %%
from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    task_type=TaskType.SEQ_CLS,
    inference_mode=False,
    r=8,
    lora_alpha=16,
    lora_dropout=0.1,
    target_modules=["query", "value"]  # encoder-based 可試 ["dense"] 或 ["dense_1"]
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# trainable params: 298,757 || all params: 102,570,250 || trainable%: 0.2913

# %%
#for n, p in model.named_parameters():
    #print(n, p.dtype)
# Out:
# base_model.model.bert.embeddings.word_embeddings.weight torch.float32
# base_model.model.bert.embeddings.position_embeddings.weight torch.float32
# base_model.model.bert.embeddings.token_type_embeddings.weight torch.float32
# base_model.model.bert.embeddings.LayerNorm.weight torch.float32
# base_model.model.bert.embeddings.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.0.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.0.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.0.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.0.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.0.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.0.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.0.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.0.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.1.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.1.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.1.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.1.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.1.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.1.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.1.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.1.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.2.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.2.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.2.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.2.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.2.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.2.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.2.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.2.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.3.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.3.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.3.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.3.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.3.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.3.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.3.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.3.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.4.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.4.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.4.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.4.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.4.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.4.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.4.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.4.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.5.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.5.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.5.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.5.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.5.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.5.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.5.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.5.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.6.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.6.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.6.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.6.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.6.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.6.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.6.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.6.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.7.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.7.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.7.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.7.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.7.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.7.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.7.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.7.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.8.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.8.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.8.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.8.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.8.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.8.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.8.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.8.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.9.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.9.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.9.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.9.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.9.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.9.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.9.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.9.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.10.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.10.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.10.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.10.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.10.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.10.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.10.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.10.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.query.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.query.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.query.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.query.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.key.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.key.bias torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.value.base_layer.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.value.base_layer.bias torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.value.lora_A.default.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.self.value.lora_B.default.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.11.attention.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.11.attention.output.LayerNorm.bias torch.float32
# base_model.model.bert.encoder.layer.11.intermediate.dense.weight torch.float32
# base_model.model.bert.encoder.layer.11.intermediate.dense.bias torch.float32
# base_model.model.bert.encoder.layer.11.output.dense.weight torch.float32
# base_model.model.bert.encoder.layer.11.output.dense.bias torch.float32
# base_model.model.bert.encoder.layer.11.output.LayerNorm.weight torch.float32
# base_model.model.bert.encoder.layer.11.output.LayerNorm.bias torch.float32
# base_model.model.bert.pooler.dense.weight torch.float32
# base_model.model.bert.pooler.dense.bias torch.float32
# base_model.model.classifier.original_module.weight torch.float32
# base_model.model.classifier.original_module.bias torch.float32
# base_model.model.classifier.modules_to_save.default.weight torch.float32
# base_model.model.classifier.modules_to_save.default.bias torch.float32

# %%
from transformers import TrainingArguments, Trainer
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

training_args = TrainingArguments(
    output_dir="./lora_model",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=10,
    learning_rate=5e-4,
    logging_strategy="steps",  # 只 log 本地，不用 wandb
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="eval_accuracy",
    fp16=False,
    report_to="none"
)

def compute_metrics(pred):
    labels = pred.label_ids
    preds = np.argmax(pred.predictions, axis=1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1_macro": f1_score(labels, preds, average="macro"),
        "precision": precision_score(labels, preds, average="macro"),
        "recall": recall_score(labels, preds, average="macro")
    }

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=ds_encoded["train"],
    eval_dataset=ds_encoded["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# /tmp/ipython-input-3613872904.py:30: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 00:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.597517</td>
#       <td>0.303030</td>
#       <td>0.158508</td>
#       <td>0.114000</td>
#       <td>0.280000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.425070</td>
#       <td>0.393939</td>
#       <td>0.267273</td>
#       <td>0.226923</td>
#       <td>0.351190</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.176634</td>
#       <td>0.454545</td>
#       <td>0.329293</td>
#       <td>0.271861</td>
#       <td>0.422857</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.160174</td>
#       <td>0.333333</td>
#       <td>0.281569</td>
#       <td>0.294545</td>
#       <td>0.347857</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.057967</td>
#       <td>0.606061</td>
#       <td>0.549394</td>
#       <td>0.585000</td>
#       <td>0.570476</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>1.164250</td>
#       <td>0.484848</td>
#       <td>0.481775</td>
#       <td>0.555714</td>
#       <td>0.468095</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>1.106468</td>
#       <td>0.636364</td>
#       <td>0.620932</td>
#       <td>0.651429</td>
#       <td>0.610952</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>1.100968</td>
#       <td>0.666667</td>
#       <td>0.643791</td>
#       <td>0.698413</td>
#       <td>0.632381</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>1.089251</td>
#       <td>0.696970</td>
#       <td>0.665329</td>
#       <td>0.711111</td>
#       <td>0.660952</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>1.067051</td>
#       <td>0.666667</td>
#       <td>0.643205</td>
#       <td>0.675000</td>
#       <td>0.635952</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TrainOutput(global_step=330, training_loss=0.8030994762073863, metrics={'train_runtime': 42.6437, 'train_samples_per_second': 30.954, 'train_steps_per_second': 7.739, 'total_flos': 87131854909440.0, 'train_loss': 0.8030994762073863, 'epoch': 10.0})

# %%
# 儲存 PEFT adapter
model.save_pretrained("./lora_model_adapter")
tokenizer.save_pretrained("./lora_model_adapter")
# Out:
# ('./lora_model_adapter/tokenizer_config.json',
#  './lora_model_adapter/special_tokens_map.json',
#  './lora_model_adapter/vocab.txt',
#  './lora_model_adapter/added_tokens.json',
#  './lora_model_adapter/tokenizer.json')

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from peft import PeftModel
import torch

base_model_name = "hfl/chinese-roberta-wwm-ext"
tokenizer = AutoTokenizer.from_pretrained(base_model_name)
base_model = AutoModelForSequenceClassification.from_pretrained(base_model_name, num_labels=5)

# 載入 LoRA adapter
model = PeftModel.from_pretrained(base_model, "./lora_model_adapter")

# 推論函數
def predict_sentence(sent):
    inputs = tokenizer(sent, return_tensors="pt", truncation=True, padding=True, max_length=128).to(model.device)
    model.eval()
    with torch.no_grad():
        logits = model(**inputs).logits
    pred = torch.argmax(logits, dim=-1).item()
    return pred + 1

print(predict_sentence("你又拿我筆？"))
print(predict_sentence("哇，你真會把事情弄得這麼亂！"))
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hfl/chinese-roberta-wwm-ext and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2
# 3
